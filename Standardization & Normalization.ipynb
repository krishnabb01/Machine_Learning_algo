# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\\Users\\Krishna Baraskar\\Downloads\\Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.drop(columns={"User ID", "Gender"},inplace=True)

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop("Purchased",axis = 1), df["Purchased"],test_size = 0.25,random_state=0)

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (300, 100, 300, 100)

# %% [markdown]
# **StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# train the parameter for standraztion
scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_test_scaled
# Out:
# array([[-0.80480212,  0.50496393],
#        [-0.01254409, -0.5677824 ],
#        [-0.30964085,  0.1570462 ],
#        [-0.80480212,  0.27301877],
#        [-0.30964085, -0.5677824 ],
#        [-1.10189888, -1.43757673],
#        [-0.70576986, -1.58254245],
#        [-0.21060859,  2.15757314],
#        [-1.99318916, -0.04590581],
#        [ 0.8787462 , -0.77073441],
#        [-0.80480212, -0.59677555],
#        [-1.00286662, -0.42281668],
#        [-0.11157634, -0.42281668],
#        [ 0.08648817,  0.21503249],
#        [-1.79512465,  0.47597078],
#        [-0.60673761,  1.37475825],
#        [-0.11157634,  0.21503249],
#        [-1.89415691,  0.44697764],
#        [ 1.67100423,  1.75166912],
#        [-0.30964085, -1.37959044],
#        [-0.30964085, -0.65476184],
#        [ 0.8787462 ,  2.15757314],
#        [ 0.28455268, -0.53878926],
#        [ 0.8787462 ,  1.02684052],
#        [-1.49802789, -1.20563157],
#        [ 1.07681071,  2.07059371],
#        [-1.00286662,  0.50496393],
#        [-0.90383437,  0.30201192],
#        [-0.11157634, -0.21986468],
#        [-0.60673761,  0.47597078],
#        [-1.6960924 ,  0.53395707],
#        [-0.11157634,  0.27301877],
#        [ 1.86906873, -0.27785096],
#        [-0.11157634, -0.48080297],
#        [-1.39899564, -0.33583725],
#        [-1.99318916, -0.50979612],
#        [-1.59706014,  0.33100506],
#        [-0.4086731 , -0.77073441],
#        [-0.70576986, -1.03167271],
#        [ 1.07681071, -0.97368642],
#        [-1.10189888,  0.53395707],
#        [ 0.28455268, -0.50979612],
#        [-1.10189888,  0.41798449],
#        [-0.30964085, -1.43757673],
#        [ 0.48261718,  1.22979253],
#        [-1.10189888, -0.33583725],
#        [-0.11157634,  0.30201192],
#        [ 1.37390747,  0.59194336],
#        [-1.20093113, -1.14764529],
#        [ 1.07681071,  0.47597078],
#        [ 1.86906873,  1.51972397],
#        [-0.4086731 , -1.29261101],
#        [-0.30964085, -0.3648304 ],
#        [-0.4086731 ,  1.31677196],
#        [ 2.06713324,  0.53395707],
#        [ 0.68068169, -1.089659  ],
#        [-0.90383437,  0.38899135],
#        [-1.20093113,  0.30201192],
#        [ 1.07681071, -1.20563157],
#        [-1.49802789, -1.43757673],
#        [-0.60673761, -1.49556302],
#        [ 2.1661655 , -0.79972756],
#        [-1.89415691,  0.18603934],
#        [-0.21060859,  0.85288166],
#        [-1.89415691, -1.26361786],
#        [ 2.1661655 ,  0.38899135],
#        [-1.39899564,  0.56295021],
#        [-1.10189888, -0.33583725],
#        [ 0.18552042, -0.65476184],
#        [ 0.38358493,  0.01208048],
#        [-0.60673761,  2.331532  ],
#        [-0.30964085,  0.21503249],
#        [-1.59706014, -0.19087153],
#        [ 0.68068169, -1.37959044],
#        [-1.10189888,  0.56295021],
#        [-1.99318916,  0.35999821],
#        [ 0.38358493,  0.27301877],
#        [ 0.18552042, -0.27785096],
#        [ 1.47293972, -1.03167271],
#        [ 0.8787462 ,  1.08482681],
#        [ 1.96810099,  2.15757314],
#        [ 2.06713324,  0.38899135],
#        [-1.39899564, -0.42281668],
#        [-1.20093113, -1.00267957],
#        [ 1.96810099, -0.91570013],
#        [ 0.38358493,  0.30201192],
#        [ 0.18552042,  0.1570462 ],
#        [ 2.06713324,  1.75166912],
#        [ 0.77971394, -0.8287207 ],
#        [ 0.28455268, -0.27785096],
#        [ 0.38358493, -0.16187839],
#        [-0.11157634,  2.21555943],
#        [-1.49802789, -0.62576869],
#        [-1.29996338, -1.06066585],
#        [-1.39899564,  0.41798449],
#        [-1.10189888,  0.76590222],
#        [-1.49802789, -0.19087153],
#        [ 0.97777845, -1.06066585],
#        [ 0.97777845,  0.59194336],
#        [ 0.38358493,  0.99784738]])

# %%
scaler.mean_
# Out:
# array([3.81266667e+01, 6.95833333e+04])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
x_test_scaled
# Out:
#          Age  EstimatedSalary
# 0  -0.804802         0.504964
# 1  -0.012544        -0.567782
# 2  -0.309641         0.157046
# 3  -0.804802         0.273019
# 4  -0.309641        -0.567782
# ..       ...              ...
# 95 -1.101899         0.765902
# 96 -1.498028        -0.190872
# 97  0.977778        -1.060666
# 98  0.977778         0.591943
# 99  0.383585         0.997847
#
# [100 rows x 2 columns]

# %%
x_train_scaled
# Out:
#           Age  EstimatedSalary
# 0    0.581649        -0.886707
# 1   -0.606738         1.461738
# 2   -0.012544        -0.567782
# 3   -0.606738         1.896635
# 4    1.373907        -1.408584
# ..        ...              ...
# 295  0.977778        -1.147645
# 296 -0.903834        -0.770734
# 297 -0.210609        -0.509796
# 298 -1.101899        -0.451810
# 299 -1.200931         1.403751
#
# [300 rows x 2 columns]

# %%
round(x_train.describe(),2)
# Out:
#           Age  EstimatedSalary
# count  300.00           300.00
# mean    38.13         69583.33
# std     10.11         34548.54
# min     18.00         15000.00
# 25%     30.75         43000.00
# 50%     38.00         69500.00
# 75%     46.00         88000.00
# max     60.00        150000.00

# %%
round(x_train_scaled.describe(),2)
# Out:
#           Age  EstimatedSalary
# count  300.00           300.00
# mean     0.00             0.00
# std      1.00             1.00
# min     -1.99            -1.58
# 25%     -0.73            -0.77
# 50%     -0.01            -0.00
# 75%      0.78             0.53
# max      2.17             2.33

# %% [markdown]
# In feacture scaling after doing standardization our mean = 0 and std = 1

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

ax1.scatter(x_train["Age"],x_train["EstimatedSalary"],c = "b")
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled["Age"],x_train_scaled["EstimatedSalary"],c = "r")
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

# Before Scaling
ax1.set_title("Before Scaling")
sns.kdeplot(x_train["Age"], ax = ax1)
sns.kdeplot(x_train["EstimatedSalary"],ax = ax1)

# After Scaling
ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled["Age"],ax = ax2)
sns.kdeplot(x_train_scaled["EstimatedSalary"], ax = ax2)

plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

# Before Scaling
ax1.set_title("Before Scaling")
sns.kdeplot(x_train["Age"], ax = ax1)

# After Scaling
ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled["Age"],ax = ax2)

plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

# Before Scaling
ax1.set_title("Before Scaling")
sns.kdeplot(x_train["EstimatedSalary"],ax = ax1)

# After Scaling
ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled["EstimatedSalary"], ax = ax2)

plt.show()

# %% [markdown]
# Why scalling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr_scaled.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
y_pred_scaled = lr_scaled.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.89
# Scaled 0.89

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
dt_scaled.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
y_pred_scaled = dt_scaled.predict(x_test_scaled)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.91
# Scaled 0.89

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# Effect of Outlier

# %%
df = pd.concat([df, pd.DataFrame({"Age": [5, 90, 95], "EstimatedSalary": [1000, 250000, 350000], "Purchased": [0, 1, 1]})], ignore_index=True)

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  403.000000       403.000000  403.000000
# mean    37.846154     70714.640199    0.359801
# std     11.255343     37959.790969    0.480539
# min      5.000000      1000.000000    0.000000
# 25%     29.500000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     95.000000    350000.000000    1.000000

# %%
plt.scatter(df["Age"],df["EstimatedSalary"])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop("Purchased",axis = 1), df["Purchased"],test_size = 0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# train the parameter for standraztion
scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([3.83278146e+01, 6.93675497e+04])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

ax1.scatter(x_train["Age"],x_train["EstimatedSalary"],c = "b")
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled["Age"],x_train_scaled["EstimatedSalary"],c = "r")
ax2.set_title("After Scaling")
plt.show()

# %% [markdown]
# "Not Effect in outliers too"

# %% [markdown]
# **Normalization**

# %%
df = pd.read_csv(r"C:\\Users\\Krishna Baraskar\\Downloads\\Wine dataset.csv",usecols = ["class","Alcohol","Malic acid"])
df
# Out:
#      class  Alcohol  Malic acid
# 0        1    14.23        1.71
# 1        1    13.20        1.78
# 2        1    13.16        2.36
# 3        1    14.37        1.95
# 4        1    13.24        2.59
# ..     ...      ...         ...
# 173      3    13.71        5.65
# 174      3    13.40        3.91
# 175      3    13.27        4.28
# 176      3    13.17        2.59
# 177      3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df["Alcohol"])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df["Malic acid"])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
sns.kdeplot(df["class"])
# Out:
# <Axes: xlabel='class', ylabel='Density'>

# %%
sns.scatterplot(x = "Alcohol",y = "Malic acid",hue = df["class"],palette="rainbow",data = df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop("class",axis=1),df["class"],test_size=0.25)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((133, 2), (45, 2), (133,), (45,))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler to the train set, it will learn the parameter
scaler.fit(x_train)

# transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[0.37426901, 0.16089613],
#        [0.54385965, 0.7209776 ],
#        [0.61111111, 0.21792261],
#        [0.71929825, 0.23625255],
#        [0.19590643, 0.12016293],
#        [0.19590643, 0.27291242],
#        [0.67836257, 0.73727088],
#        [0.35964912, 0.12627291],
#        [0.69298246, 0.4114053 ],
#        [0.51169591, 0.3299389 ],
#        [0.04385965, 0.26680244],
#        [0.62865497, 0.20162933],
#        [0.51461988, 0.37678208],
#        [0.34795322, 0.12219959],
#        [0.64912281, 0.21792261],
#        [0.01169591, 0.33808554],
#        [0.17251462, 0.03665988],
#        [0.23391813, 0.09164969],
#        [0.40350877, 0.39307536],
#        [0.44444444, 0.42158859],
#        [0.85672515, 0.19144603],
#        [0.42982456, 0.45824847],
#        [0.57017544, 0.3706721 ],
#        [0.60526316, 0.21792261],
#        [0.60818713, 0.18737271],
#        [0.71052632, 0.68839104],
#        [0.40935673, 0.3197556 ],
#        [0.53508772, 0.6598778 ],
#        [0.81578947, 0.20773931],
#        [1.        , 0.18329939],
#        [0.4619883 , 0.18940937],
#        [0.73976608, 0.20162933],
#        [0.70760234, 0.18533605],
#        [0.71637427, 0.12423625],
#        [0.06725146, 0.2688391 ],
#        [0.07017544, 0.18940937],
#        [0.10233918, 0.39511202],
#        [0.78654971, 0.26069246],
#        [0.49707602, 0.05498982],
#        [0.38304094, 0.21792261],
#        [0.48538012, 0.15478615],
#        [0.30994152, 0.15885947],
#        [0.60818713, 0.58044807],
#        [0.72222222, 0.87576375],
#        [0.56432749, 0.0407332 ],
#        [0.19298246, 0.2892057 ],
#        [0.54678363, 0.18329939],
#        [0.82163743, 0.66191446],
#        [0.86842105, 0.23014257],
#        [0.25730994, 0.42566191],
#        [0.25730994, 0.17718941],
#        [0.47953216, 0.26680244],
#        [0.86842105, 0.58044807],
#        [0.28070175, 0.0407332 ],
#        [0.79532164, 0.68431772],
#        [0.26900585, 0.07331976],
#        [0.70467836, 0.20570265],
#        [0.69005848, 0.23625255],
#        [0.39766082, 0.33604888],
#        [0.58187135, 0.78615071],
#        [0.        , 0.        ],
#        [0.28070175, 0.09572301],
#        [0.61695906, 0.49490835],
#        [0.05847953, 0.12423625],
#        [0.47953216, 0.63543788],
#        [0.13450292, 0.72708758],
#        [0.18421053, 0.72505092],
#        [0.32748538, 0.97148676],
#        [0.62865497, 0.19755601],
#        [0.34210526, 0.11201629],
#        [0.11111111, 0.28309572],
#        [0.47953216, 0.20977597],
#        [0.86549708, 0.24643585],
#        [0.19590643, 0.22199593],
#        [0.6754386 , 0.14052953],
#        [0.12573099, 0.43788187],
#        [0.42690058, 0.78818737],
#        [0.25730994, 0.13645621],
#        [0.78654971, 0.2892057 ],
#        [0.23099415, 0.46639511],
#        [0.17251462, 0.54786151],
#        [0.67251462, 0.22810591],
#        [0.53216374, 0.52138493],
#        [0.29532164, 0.17718941],
#        [0.22222222, 0.14460285],
#        [0.49707602, 0.23625255],
#        [0.17251462, 0.15682281],
#        [0.81871345, 0.67209776],
#        [0.68128655, 0.18940937],
#        [0.36842105, 0.04887984],
#        [0.48830409, 0.64358452],
#        [0.58187135, 0.64562118],
#        [0.42397661, 0.12423625],
#        [0.84502924, 0.24032587],
#        [0.23684211, 0.11201629],
#        [0.61403509, 0.21588595],
#        [0.8245614 , 0.19755601],
#        [0.52339181, 0.21181263],
#        [0.38304094, 0.20570265],
#        [0.26900585, 0.0509165 ],
#        [0.19590643, 0.07942974],
#        [0.01461988, 0.61099796],
#        [0.61111111, 0.48472505],
#        [0.60526316, 0.18940937],
#        [0.80409357, 0.3604888 ],
#        [0.72222222, 0.23421589],
#        [0.51461988, 0.90631365],
#        [0.64619883, 0.85743381],
#        [0.3245614 , 0.34419552],
#        [0.63450292, 0.18737271],
#        [0.44444444, 0.62321792],
#        [0.67251462, 1.        ],
#        [0.28070175, 0.18126273],
#        [0.16081871, 0.0712831 ],
#        [0.19590643, 0.13238289],
#        [0.66081871, 0.10386965],
#        [0.29532164, 0.75152749],
#        [0.4122807 , 0.53564155],
#        [0.45321637, 0.55193483],
#        [0.66374269, 0.22199593],
#        [0.24561404, 0.20162933],
#        [0.29532164, 0.36863544],
#        [0.47953216, 0.18533605],
#        [0.5497076 , 0.25050916],
#        [0.28070175, 0.07942974],
#        [0.27192982, 0.34826884],
#        [0.6871345 , 0.16089613],
#        [0.29824561, 0.16089613],
#        [0.24561404, 0.6395112 ],
#        [0.8128655 , 0.17311609],
#        [0.12573099, 0.0305499 ],
#        [0.66666667, 0.51323829],
#        [0.25730994, 0.49490835]])

# %%
x_test_scaled
# Out:
# array([[ 0.30409357,  0.46639511],
#        [ 0.72807018,  0.19144603],
#        [ 0.71637427,  0.15682281],
#        [ 0.70760234,  0.16904277],
#        [ 0.32163743,  0.20162933],
#        [ 0.67836257,  0.15478615],
#        [ 0.11695906,  0.28105906],
#        [ 0.82163743,  0.19551935],
#        [ 0.11988304,  0.19959267],
#        [ 0.58479532,  0.63136456],
#        [ 0.68421053,  0.20162933],
#        [ 0.21929825,  0.17718941],
#        [ 0.28070175,  0.08757637],
#        [ 0.11988304,  0.14867617],
#        [ 0.41812865,  0.45213849],
#        [ 0.79239766,  0.15071283],
#        [ 0.7748538 ,  0.28716904],
#        [ 0.39766082,  0.54786151],
#        [ 0.42105263,  0.17515275],
#        [ 0.42105263,  0.51527495],
#        [ 0.55263158,  0.19959267],
#        [ 0.32163743,  0.10183299],
#        [-0.11111111,  0.15682281],
#        [ 0.53508772,  0.37678208],
#        [ 0.06140351,  0.25458248],
#        [ 0.51169591,  0.57637475],
#        [ 0.47368421,  0.03258656],
#        [ 0.47953216,  0.20162933],
#        [ 0.63450292,  0.37474542],
#        [ 0.24561404,  0.81059063],
#        [ 0.97660819,  0.20162933],
#        [ 0.57894737,  0.20977597],
#        [ 0.59649123,  0.60285132],
#        [ 0.76315789,  0.19144603],
#        [ 0.65204678,  0.48065173],
#        [ 0.47953216,  1.0305499 ],
#        [ 0.27777778,  0.6293279 ],
#        [ 0.34795322,  0.3503055 ],
#        [ 0.37719298,  0.63747454],
#        [ 0.7748538 ,  0.18126273],
#        [ 0.55847953,  0.50916497],
#        [ 0.87134503,  0.23014257],
#        [ 0.37719298,  0.57230143],
#        [ 0.28070175,  0.06720978],
#        [ 0.07309942,  0.23217923]])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
x_train_scaled.head()
# Out:
#     Alcohol  Malic acid
# 0  0.374269    0.160896
# 1  0.543860    0.720978
# 2  0.611111    0.217923
# 3  0.719298    0.236253
# 4  0.195906    0.120163

# %%
x_test_scaled.head()
# Out:
#     Alcohol  Malic acid
# 0  0.304094    0.466395
# 1  0.728070    0.191446
# 2  0.716374    0.156823
# 3  0.707602    0.169043
# 4  0.321637    0.201629

# %%
round(x_train.describe(),2)
# Out:
#        Alcohol  Malic acid
# count   133.00      133.00
# mean     12.99        2.34
# std       0.80        1.14
# min      11.41        0.74
# 25%      12.33        1.59
# 50%      13.05        1.87
# 75%      13.67        3.03
# max      14.83        5.65

# %%
round(x_train_scaled.describe(),2)
# Out:
#        Alcohol  Malic acid
# count   133.00      133.00
# mean      0.46        0.33
# std       0.23        0.23
# min       0.00        0.00
# 25%       0.27        0.17
# 50%       0.48        0.23
# 75%       0.66        0.47
# max       1.00        1.00

# %% [markdown]
# In Feacture scalling after doing Normalization min-max All values are lies in 0 to 1

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

ax1.scatter(x_train["Alcohol"],x_train["Malic acid"],c = y_train)
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled["Alcohol"],x_train_scaled["Malic acid"],c = y_train)
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

# before scaling
sns.kdeplot(x_train["Alcohol"],ax=ax1,label = "Alcohol")
sns.kdeplot(x_train["Malic acid"],ax = ax1, label = "Malic acid")
ax1.set_title("Before Scaling")
ax1.legend()

sns.kdeplot(x_train_scaled["Alcohol"],ax=ax2,label = "Alcohol")
sns.kdeplot(x_train_scaled["Malic acid"],ax = ax2,label = "Malic acid")
ax2.set_title("After Scaling")
ax2.legend()
plt.show()
# sns.kdeplot(df["Alcohol"])

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

# before scaling
sns.kdeplot(x_train["Alcohol"],ax=ax1,label = "Alcohol")
ax1.set_title("Before Scaling")
ax1.legend()

sns.kdeplot(x_train_scaled["Alcohol"],ax=ax2,label = "Alcohol")
ax2.set_title("After Scaling")
ax2.legend()
plt.show()
# sns.kdeplot(df["Alcohol"])

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,figsize = (12,5))

# before scaling
sns.kdeplot(x_train["Malic acid"],ax = ax1, label = "Malic acid")
ax1.set_title("Before Scaling")
ax1.legend()

sns.kdeplot(x_train_scaled["Malic acid"],ax = ax2,label = "Malic acid")
ax2.set_title("After Scaling")
ax2.legend()
plt.show()
# sns.kdeplot(df["Alcohol"])
